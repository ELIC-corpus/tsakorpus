# %% [markdown]
# # Setting up Tsakorpus on the Corpus Server
# *Agustin Lorenzo, agustin.lorenzo@uga.edu*

# %% [markdown]
# These are all the steps taken to upload annotated ELIC files to a corpus hosted on the UGA corpus server. The corpus is created using the open-source [Tsakorpus framework](https://github.com/timarkh/tsakorpus). All steps follow what is described in the [docs](https://tsakorpus.readthedocs.io/en/latest/), along with specific steps taken specifically for setup on the corpus server (i.e. changing necesssary code, downloading appropriate software versions, etc). Everything is done through terminal commands, given that the server is most likely being accessed through SSH.
#
# If there are any questions or issues with setup, feel free to contact me for help at the email above.

# %% [markdown]
# ### Format
# All `Shell Script` code blocks are commands run in the terminal (or expected outputs from the terminal after running a given command). All `Python` or `raw` code blocks are what should be put in the implied file it follows in the previous shell script command. i.e. ...

# %%
emacs file.txt # open a file with a text editor

# %% [raw]
# This is the contents of file.txt

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# Create a `venv` environment for Python packages

# %%
python -m venv korpusenv
source korpusenv/activate

# %% [markdown]
# Download the Tsakorpus repository

# %%
git clone https://github.com/timarkh/tsakorpus.git
cd tsakorpus/

# %% [markdown]
# Change `corpus.json` settings in the `/conf/` folder to match these settings

# %%
cd conf
rm corpus.json
emacs corpus.json

# %% [raw]
# {
#   "accidental_word_fields": [],
#   "all_language_search_enabled": false,
#   "ambiguous_analyses": true,
#   "author_metafield": "",
#   "auto_switch_tiers": {},
#   "case_sensitive_meta_fields": [],
#   "citation": "ELIC corpus.",
#   "context_header_rtl": false,
#   "corpus_name": "elic",
#   "debug": false,
#   "default_locale": "en",
#   "default_values": {
#     "sent_meta_speaker_type": "native"
#   },
#   "default_view": "standard",
#   "detect_lemma_queries": false,
#   "display_freq_rank": true,
#   "fulltext_page_size": 100,
#   "fulltext_search_enabled": true,
#   "fulltext_view_enabled": true,
#   "generate_dictionary": true,
#   "gloss_search_enabled": true,
#   "images": false,
#   "input_format": "json",
#   "input_methods": [
#     "normal"
#   ],
#   "integer_meta_fields": [],
#   "interface_languages": [
#     "en",
#     "ru",
#     "fr"
#   ],
#   "keep_lemma_order": false,
#   "keyboards": {
#     "chakavian": "chakavian",
#     "english": "english"
#   },
#   "lang_props": {
#     "chakavian": {
#       "dictionary_categories": [
#         "nType",
#         "adjType",
#         "proType",
#         "conjtype",
#         "additional"
#       ],
#       "gloss_selection": {
#         "columns": [
#           [
#             {
#               "tooltip": "Any&nbsp;case&nbsp;marker",
#               "type": "tag",
#               "value": "CASE"
#             },
#             {
#               "tooltip": "Nominative case",
#               "type": "tag",
#               "value": "NOM"
#             },
#             {
#               "tooltip": "Marked accusative case",
#               "type": "tag",
#               "value": "ACC"
#             },
#             {
#               "tooltip": "Accusative (plural) case",
#               "type": "tag",
#               "value": "ACC.PL"
#             },
#             {
#               "tooltip": "Genitive case",
#               "type": "tag",
#               "value": "GEN"
#             },
#             {
#               "tooltip": "2nd genitive (Ablative) case",
#               "type": "tag",
#               "value": "GEN2"
#             },
#             {
#               "tooltip": "Dative case",
#               "type": "tag",
#               "value": "DAT"
#             },
#             {
#               "tooltip": "Instrumental case",
#               "type": "tag",
#               "value": "INS"
#             },
#             {
#               "tooltip": "Caritive case",
#               "type": "tag",
#               "value": "CAR"
#             },
#             {
#               "tooltip": "Adverbial case",
#               "type": "tag",
#               "value": "ADV"
#             }
#           ],
#           [
#             {
#               "tooltip": "Locative case",
#               "type": "tag",
#               "value": "LOC"
#             },
#             {
#               "tooltip": "Illative case",
#               "type": "tag",
#               "value": "ILL"
#             },
#             {
#               "tooltip": "Elative case",
#               "type": "tag",
#               "value": "EL"
#             },
#             {
#               "tooltip": "Egressive case",
#               "type": "tag",
#               "value": "EGR"
#             },
#             {
#               "tooltip": "Terminative case",
#               "type": "tag",
#               "value": "TERM"
#             },
#             {
#               "tooltip": "Prolative case",
#               "type": "tag",
#               "value": "PROL"
#             },
#             {
#               "tooltip": "Approximative case",
#               "type": "tag",
#               "value": "APP"
#             },
#             {
#               "tooltip": "Recessive case",
#               "type": "tag",
#               "value": "RCS"
#             },
#             {
#               "tooltip": "",
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "tooltip": "&ldquo;Domus&rdquo; (personal-local marker)",
#               "type": "tag",
#               "value": "DMS"
#             }
#           ],
#           [
#             {
#               "tooltip": "Nominal plural",
#               "type": "tag",
#               "value": "PL"
#             },
#             {
#               "tooltip": "Adjectival plural",
#               "type": "tag",
#               "value": "ADJ.PL"
#             },
#             {
#               "tooltip": "",
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "tooltip": "Any&nbsp;possessive&nbsp;marker",
#               "type": "tag",
#               "value": "POSS"
#             },
#             {
#               "tooltip": "1sg possessive",
#               "type": "tag",
#               "value": "P.1SG"
#             },
#             {
#               "tooltip": "1pl possessive",
#               "type": "tag",
#               "value": "P.1PL"
#             },
#             {
#               "tooltip": "2sg possessive",
#               "type": "tag",
#               "value": "P.2SG"
#             },
#             {
#               "tooltip": "2pl possessive",
#               "type": "tag",
#               "value": "P.2PL"
#             },
#             {
#               "tooltip": "3sg possessive",
#               "type": "tag",
#               "value": "P.3SG"
#             },
#             {
#               "tooltip": "3pl possessive",
#               "type": "tag",
#               "value": "P.3PL"
#             }
#           ],
#           [
#             {
#               "tooltip": "Any possessive accusative",
#               "type": "tag",
#               "value": "P.ACC"
#             },
#             {
#               "tooltip": "Accusative 1sg possessive",
#               "type": "tag",
#               "value": "P.1SG.ACC"
#             },
#             {
#               "tooltip": "Accusative 1pl possessive",
#               "type": "tag",
#               "value": "P.1PL.ACC"
#             },
#             {
#               "tooltip": "Accusative 2sg possessive",
#               "type": "tag",
#               "value": "P.2SG.ACC"
#             },
#             {
#               "tooltip": "Accusative 2pl possessive",
#               "type": "tag",
#               "value": "P.2PL.ACC"
#             },
#             {
#               "tooltip": "Accusative 3sg possessive",
#               "type": "tag",
#               "value": "P.3SG.ACC"
#             },
#             {
#               "tooltip": "Accusative 3pl possessive",
#               "type": "tag",
#               "value": "P.3PL.ACC"
#             },
#             {
#               "tooltip": "",
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "tooltip": "Attributivizer",
#               "type": "tag",
#               "value": "ATTR"
#             },
#             {
#               "tooltip": "Negative attributivizer",
#               "type": "tag",
#               "value": "NEG.ATTR"
#             }
#           ],
#           [
#             {
#               "tooltip": "Ordinal numeral",
#               "type": "tag",
#               "value": "ORD"
#             },
#             {
#               "tooltip": "Distributive numeral",
#               "type": "tag",
#               "value": "DISTR"
#             },
#             {
#               "tooltip": "Collective numeral",
#               "type": "tag",
#               "value": "COLL"
#             },
#             {
#               "tooltip": "Time period (-oj)",
#               "type": "tag",
#               "value": "PERIOD"
#             },
#             {
#               "tooltip": "Delimitative (-skən)",
#               "type": "tag",
#               "value": "DELIM"
#             },
#             {
#               "tooltip": "",
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "tooltip": "Verbal noun (-on)",
#               "type": "tag",
#               "value": "VN"
#             },
#             {
#               "tooltip": "Locative noun (-nʼig)",
#               "type": "tag",
#               "value": "NLOC"
#             },
#             {
#               "tooltip": "&ldquo;Comparative&rdquo;",
#               "type": "tag",
#               "value": "COMP"
#             }
#           ],
#           [
#             {
#               "tooltip": "Any verbal derivation",
#               "type": "tag",
#               "value": "DERIV"
#             },
#             {
#               "tooltip": "Iterative",
#               "type": "tag",
#               "value": "ITER"
#             },
#             {
#               "tooltip": "Causative",
#               "type": "tag",
#               "value": "CAUS"
#             },
#             {
#               "tooltip": "Detransitive",
#               "type": "tag",
#               "value": "DETR"
#             },
#             {
#               "tooltip": "",
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "tooltip": "Present 1sg",
#               "type": "tag",
#               "value": "PRS.1SG"
#             },
#             {
#               "tooltip": "Present 1pl",
#               "type": "tag",
#               "value": "PRS.1PL"
#             },
#             {
#               "tooltip": "Present 2sg",
#               "type": "tag",
#               "value": "PRS.2SG"
#             },
#             {
#               "tooltip": "Present 2pl",
#               "type": "tag",
#               "value": "PRS.2PL"
#             },
#             {
#               "tooltip": "Present 3sg",
#               "type": "tag",
#               "value": "PRS.3SG"
#             },
#             {
#               "tooltip": "Present 3pl",
#               "type": "tag",
#               "value": "PRS.3PL"
#             }
#           ],
#           [
#             {
#               "tooltip": "Any past marker",
#               "type": "tag",
#               "value": "PST_ANY"
#             },
#             {
#               "tooltip": "Past (non-fusional)",
#               "type": "tag",
#               "value": "PST"
#             },
#             {
#               "tooltip": "Past 1sg (-i)",
#               "type": "tag",
#               "value": "PST(1SG)"
#             },
#             {
#               "tooltip": "Past 1sg (-j)",
#               "type": "tag",
#               "value": "PST.1SG"
#             },
#             {
#               "tooltip": "Past 1pl",
#               "type": "tag",
#               "value": "PST.1PL"
#             },
#             {
#               "tooltip": "Past 2sg",
#               "type": "tag",
#               "value": "PST.2SG"
#             },
#             {
#               "tooltip": "Past 2pl",
#               "type": "tag",
#               "value": "PST.2PL"
#             },
#             {
#               "tooltip": "Past 3sg",
#               "type": "tag",
#               "value": "PST.3SG"
#             },
#             {
#               "tooltip": "Past 3pl",
#               "type": "tag",
#               "value": "PST.3PL"
#             }
#           ],
#           [
#             {
#               "tooltip": "Any future marker",
#               "type": "tag",
#               "value": "FUT_ANY"
#             },
#             {
#               "tooltip": "Future (non-fusional)",
#               "type": "tag",
#               "value": "FUT"
#             },
#             {
#               "tooltip": "Future 1sg (-i)",
#               "type": "tag",
#               "value": "FUT(1SG)"
#             },
#             {
#               "tooltip": "Future 1sg (-j)",
#               "type": "tag",
#               "value": "FUT.1SG"
#             },
#             {
#               "tooltip": "Future 1pl",
#               "type": "tag",
#               "value": "FUT.1PL"
#             },
#             {
#               "tooltip": "Future 2sg",
#               "type": "tag",
#               "value": "FUT.2SG"
#             },
#             {
#               "tooltip": "Future 2pl",
#               "type": "tag",
#               "value": "FUT.2PL"
#             },
#             {
#               "tooltip": "Future 3sg",
#               "type": "tag",
#               "value": "FUT.3SG"
#             },
#             {
#               "tooltip": "Future 3pl",
#               "type": "tag",
#               "value": "FUT.3PL"
#             }
#           ],
#           [
#             {
#               "tooltip": "2nd (evidential) past",
#               "type": "tag",
#               "value": "PST2"
#             },
#             {
#               "tooltip": "",
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "tooltip": "Any person marker",
#               "type": "tag",
#               "value": "PERS"
#             },
#             {
#               "tooltip": "1st peron (in 2nd past)",
#               "type": "tag",
#               "value": "1"
#             },
#             {
#               "tooltip": "1st person singular",
#               "type": "tag",
#               "value": "1SG"
#             },
#             {
#               "tooltip": "1st person plural",
#               "type": "tag",
#               "value": "1PL"
#             },
#             {
#               "tooltip": "2nd person singular",
#               "type": "tag",
#               "value": "2SG"
#             },
#             {
#               "tooltip": "2nd person plural",
#               "type": "tag",
#               "value": "2PL"
#             },
#             {
#               "tooltip": "3rd person singular",
#               "type": "tag",
#               "value": "3SG"
#             },
#             {
#               "tooltip": "3rd person plural",
#               "type": "tag",
#               "value": "3PL"
#             }
#           ],
#           [
#             {
#               "tooltip": "General converb",
#               "type": "tag",
#               "value": "CVB"
#             },
#             {
#               "tooltip": "General negative converb",
#               "type": "tag",
#               "value": "CVB.NEG"
#             },
#             {
#               "tooltip": "Durative converb",
#               "type": "tag",
#               "value": "CVB.DUR"
#             },
#             {
#               "tooltip": "Resultative",
#               "type": "tag",
#               "value": "RES"
#             },
#             {
#               "tooltip": "Debitive",
#               "type": "tag",
#               "value": "DEB"
#             },
#             {
#               "tooltip": "Limitative converb",
#               "type": "tag",
#               "value": "CVB.LIM"
#             },
#             {
#               "tooltip": "Converb in -mon",
#               "type": "tag",
#               "value": "CVB.MON"
#             },
#             {
#               "tooltip": "Past participle",
#               "type": "tag",
#               "value": "PTCP.PST"
#             },
#             {
#               "tooltip": "Active participle",
#               "type": "tag",
#               "value": "PTCP.ACT"
#             },
#             {
#               "tooltip": "Negative active participle",
#               "type": "tag",
#               "value": "PTCP.NEG.ACT"
#             },
#             {
#               "tooltip": "Negative passive participle",
#               "type": "tag",
#               "value": "PTCP.NEG.PASS"
#             }
#           ]
#         ]
#       },
#       "gloss_shortcuts": {
#         "case": "(nom|gen2?|acc|dat|ins|loc|ill|el|egr|term|prol|car|app|rcs|adv|dms)(\\.(sg|pl))?",
#         "deriv": "(detr|iter|caus)",
#         "fut_any": "(fut(\\(1sg\\)|\\.[123](sg|pl))?)",
#         "p.acc": "(p\\.[123](sg|pl)\\.acc)",
#         "pers": "[123](sg|pl)?",
#         "poss": "(p\\.[123](sg|pl)(\\.acc)?)",
#         "pst_any": "(pst(\\(1sg\\)|\\.[123](sg|pl))?)",
#         "tense": "(pst2?|prs|fut|evid)(\\.[123](sg|pl)?)?"
#       },
#       "gr_fields_order": [
#         "nType",
#         "adjType",
#         "proType",
#         "conjtype",
#         "additional",
#         "stemType",
#         "num_deriv",
#         "v_form",
#         "attributivizer",
#         "tense",
#         "person",
#         "number",
#         "case",
#         "poss"
#       ],
#       "gramm_selection": {
#         "columns": [
#           [
#             {
#               "type": "header",
#               "value": "Parts of speech"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Noun",
#               "type": "tag",
#               "value": "N"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Verb",
#               "type": "tag",
#               "value": "V"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Adjective",
#               "type": "tag",
#               "value": "A"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Adverb",
#               "type": "tag",
#               "value": "ADV"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Predicative",
#               "type": "tag",
#               "value": "PRED"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Numeral",
#               "type": "tag",
#               "value": "NUM"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Pronoun",
#               "type": "tag",
#               "value": "PRO"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Postposition",
#               "type": "tag",
#               "value": "POST"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Conjunction",
#               "type": "tag",
#               "value": "CONJ"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Particle",
#               "type": "tag",
#               "value": "PART"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Interjection",
#               "type": "tag",
#               "value": "INTERJ"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Ideophone",
#               "type": "tag",
#               "value": "IMIT"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Lexical classes"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Relational noun",
#               "type": "tag",
#               "value": "rel_n"
#             },
#             {
#               "category": "adjType",
#               "tooltip": "Relational adjective",
#               "type": "tag",
#               "value": "rel_adj"
#             },
#             {
#               "category": "adjType",
#               "tooltip": "Oblinative (-ešʼ)",
#               "type": "tag",
#               "value": "oblin"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Place name",
#               "type": "tag",
#               "value": "topn"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Personal name",
#               "type": "tag",
#               "value": "persn"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Last name",
#               "type": "tag",
#               "value": "famn"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Patronymic",
#               "type": "tag",
#               "value": "patrn"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Animate",
#               "type": "tag",
#               "value": "anim"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Human",
#               "type": "tag",
#               "value": "hum"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Supernatural",
#               "type": "tag",
#               "value": "supernat"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Body part",
#               "type": "tag",
#               "value": "body"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Transport",
#               "type": "tag",
#               "value": "transport"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Pronoun types"
#             },
#             {
#               "category": "proType",
#               "tooltip": "Demonstrative pronoun",
#               "type": "tag",
#               "value": "dem"
#             },
#             {
#               "category": "proType",
#               "tooltip": "Personal pronoun",
#               "type": "tag",
#               "value": "pers"
#             },
#             {
#               "category": "proType",
#               "tooltip": "Reflexive pronoun",
#               "type": "tag",
#               "value": "refl"
#             },
#             {
#               "type": "header",
#               "value": "Attributivizers"
#             },
#             {
#               "category": "attr",
#               "tooltip": "Any attributivizer",
#               "type": "tag",
#               "value": "attr"
#             },
#             {
#               "category": "attr",
#               "tooltip": "-o",
#               "type": "tag",
#               "value": "attr_o"
#             },
#             {
#               "category": "attr",
#               "tooltip": "-jem",
#               "type": "tag",
#               "value": "attr_em"
#             },
#             {
#               "category": "attr",
#               "tooltip": "Negative (-tem)",
#               "type": "tag",
#               "value": "attr_tem"
#             },
#             {
#               "type": "header",
#               "value": "Numerals"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Ordinal",
#               "type": "tag",
#               "value": "ord"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Period (-skən)",
#               "type": "tag",
#               "value": "period"
#             },
#             {
#               "category": "nType",
#               "tooltip": "Collective",
#               "type": "tag",
#               "value": "coll"
#             },
#             {
#               "type": "header",
#               "value": "Loanwords"
#             },
#             {
#               "category": "additional",
#               "tooltip": "Russian borrowing",
#               "type": "tag",
#               "value": "rus"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Core cases"
#             },
#             {
#               "category": "case",
#               "tooltip": "Nominative (or unmarked accusative)",
#               "type": "tag",
#               "value": "nom"
#             },
#             {
#               "category": "case",
#               "tooltip": "Accusative",
#               "type": "tag",
#               "value": "acc"
#             },
#             {
#               "category": "case",
#               "tooltip": "Genitive",
#               "type": "tag",
#               "value": "gen"
#             },
#             {
#               "category": "case",
#               "tooltip": "2nd genitive (ablative)",
#               "type": "tag",
#               "value": "gen2"
#             },
#             {
#               "category": "case",
#               "tooltip": "Dative",
#               "type": "tag",
#               "value": "dat"
#             },
#             {
#               "category": "case",
#               "tooltip": "Instrumental",
#               "type": "tag",
#               "value": "ins"
#             },
#             {
#               "category": "case",
#               "tooltip": "Caritive",
#               "type": "tag",
#               "value": "car"
#             },
#             {
#               "category": "case",
#               "tooltip": "Adverbial",
#               "type": "tag",
#               "value": "adv"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Spatial cases"
#             },
#             {
#               "category": "case",
#               "tooltip": "Locative",
#               "type": "tag",
#               "value": "loc"
#             },
#             {
#               "category": "case",
#               "tooltip": "Illative",
#               "type": "tag",
#               "value": "ill"
#             },
#             {
#               "category": "case",
#               "tooltip": "Elative",
#               "type": "tag",
#               "value": "el"
#             },
#             {
#               "category": "case",
#               "tooltip": "Egressive",
#               "type": "tag",
#               "value": "egr"
#             },
#             {
#               "category": "case",
#               "tooltip": "Terminative",
#               "type": "tag",
#               "value": "term"
#             },
#             {
#               "category": "case",
#               "tooltip": "Prolative",
#               "type": "tag",
#               "value": "prol"
#             },
#             {
#               "category": "case",
#               "tooltip": "Approximative",
#               "type": "tag",
#               "value": "app"
#             },
#             {
#               "category": "case",
#               "tooltip": "Recessive",
#               "type": "tag",
#               "value": "rcs"
#             },
#             {
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "category": "case",
#               "tooltip": "&ldquo;Domus&rdquo; (personal-local marker)",
#               "type": "tag",
#               "value": "dms"
#             }
#           ],
#           [
#             {
#               "category": "stemType",
#               "tooltip": "Oblique stem",
#               "type": "tag",
#               "value": "obl"
#             },
#             {
#               "category": "add",
#               "tooltip": "Case compounding",
#               "type": "tag",
#               "value": "case_comp"
#             },
#             {
#               "type": "header",
#               "value": "Possessiveness"
#             },
#             {
#               "category": "poss",
#               "tooltip": "1sg possessive",
#               "type": "tag",
#               "value": "1sg"
#             },
#             {
#               "category": "poss",
#               "tooltip": "1pl possessive",
#               "type": "tag",
#               "value": "1pl"
#             },
#             {
#               "category": "poss",
#               "tooltip": "2sg possessive",
#               "type": "tag",
#               "value": "2sg"
#             },
#             {
#               "category": "poss",
#               "tooltip": "2pl possessive",
#               "type": "tag",
#               "value": "2pl"
#             },
#             {
#               "category": "poss",
#               "tooltip": "3sg possessive",
#               "type": "tag",
#               "value": "3sg"
#             },
#             {
#               "category": "poss",
#               "tooltip": "3pl possessive",
#               "type": "tag",
#               "value": "3pl"
#             },
#             {
#               "type": "header",
#               "value": "Number"
#             },
#             {
#               "category": "number",
#               "tooltip": "Singular",
#               "type": "tag",
#               "value": "sg"
#             },
#             {
#               "category": "number",
#               "tooltip": "Plural",
#               "type": "tag",
#               "value": "pl"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Tense/Mood"
#             },
#             {
#               "category": "tense",
#               "tooltip": "Present tense",
#               "type": "tag",
#               "value": "prs"
#             },
#             {
#               "category": "tense",
#               "tooltip": "Future tense",
#               "type": "tag",
#               "value": "fut"
#             },
#             {
#               "category": "tense",
#               "tooltip": "Past tense",
#               "type": "tag",
#               "value": "pst"
#             },
#             {
#               "category": "tense",
#               "tooltip": "Evidential past",
#               "type": "tag",
#               "value": "pst2"
#             },
#             {
#               "category": "tense",
#               "tooltip": "Subjunctive",
#               "type": "tag",
#               "value": "subj"
#             },
#             {
#               "type": "header",
#               "value": "Verbal derivation"
#             },
#             {
#               "category": "deriv",
#               "tooltip": "Iterative",
#               "type": "tag",
#               "value": "iter"
#             },
#             {
#               "category": "deriv",
#               "tooltip": "Causative",
#               "type": "tag",
#               "value": "caus"
#             },
#             {
#               "category": "deriv",
#               "tooltip": "Detransitive",
#               "type": "tag",
#               "value": "detr"
#             },
#             {
#               "category": "deriv",
#               "tooltip": "Verbal noun (-on)",
#               "type": "tag",
#               "value": "vn"
#             },
#             {
#               "category": "deriv",
#               "tooltip": "Nomen loci (-onʼnʼig)",
#               "type": "tag",
#               "value": "nloc"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Non-finite forms"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Infinitive",
#               "type": "tag",
#               "value": "inf"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Any participle",
#               "type": "tag",
#               "value": "ptcp"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Active (-išʼ/-əšʼ)",
#               "type": "tag",
#               "value": "ptcp,act"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Active negative (-tem)",
#               "type": "tag",
#               "value": "ptcp,act,neg"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Passive negative (-mte)",
#               "type": "tag",
#               "value": "ptcp,pass,neg"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Past participle (-em)",
#               "type": "tag",
#               "value": "ptcp,pst"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Resultative (-mən)",
#               "type": "tag",
#               "value": "res"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Debitive (-ono)",
#               "type": "tag",
#               "value": "deb"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Converbs"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Any converb",
#               "type": "tag",
#               "value": "cvb"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Durative (-onʼnʼa)",
#               "type": "tag",
#               "value": "cvb,dur"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Limitative (-čʼožʼ)",
#               "type": "tag",
#               "value": "cvb,lim"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Simultaneous (-ku)",
#               "type": "tag",
#               "value": "cvb,simult"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Negative (-tek)",
#               "type": "tag",
#               "value": "cvb,neg"
#             },
#             {
#               "type": "header",
#               "value": "Imperatives"
#             },
#             {
#               "category": "nonfin",
#               "tooltip": "Imperative",
#               "type": "tag",
#               "value": "imp"
#             },
#             {
#               "type": "header",
#               "value": "Transitivity"
#             },
#             {
#               "category": "vTr",
#               "tooltip": "Transitive",
#               "type": "tag",
#               "value": "tr"
#             },
#             {
#               "category": "vTr",
#               "tooltip": "Intransitive",
#               "type": "tag",
#               "value": "intr"
#             },
#             {
#               "category": "vTr",
#               "tooltip": "Impersonal",
#               "type": "tag",
#               "value": "impers"
#             }
#           ]
#         ]
#       },
#       "gramm_shortcuts": {
#         "NV": "(N|V)",
#         "V_nderiv": "V,~(caus|detr|iter)"
#       }
#     },
#     "english": {
#       "dictionary_categories": [
#         "an",
#         "nType",
#         "tr"
#       ],
#       "gloss_shortcuts": {
#         "case": "(nom|gen|gen2|dat|acc|acc2|ins|loc|loc2|voc)",
#         "pers": "(([123](sg|pl)|rel|rec|rfl)\\.(abs|erg|io))",
#         "tense": "(praet|fut|praes)"
#       },
#       "gr_fields_order": [
#         "nType",
#         "an",
#         "tr",
#         "asp",
#         "mood",
#         "vF",
#         "cnvF",
#         "voice",
#         "tense",
#         "g",
#         "adjF",
#         "num",
#         "case",
#         "0",
#         "add"
#       ],
#       "gramm_selection": {
#         "columns": [
#           [
#             {
#               "type": "header",
#               "value": "Parts of speech"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Noun",
#               "type": "tag",
#               "value": "S"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Verb",
#               "type": "tag",
#               "value": "V"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Adjective",
#               "type": "tag",
#               "value": "A"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Adverb",
#               "type": "tag",
#               "value": "ADV"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Predicative",
#               "type": "tag",
#               "value": "PRAEDIC"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Numeral",
#               "type": "tag",
#               "value": "NUM"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Numeral Adjective",
#               "type": "tag",
#               "value": "ANUM"
#             }
#           ],
#           [
#             {
#               "category": "pos",
#               "tooltip": "Substantive Pronoun",
#               "type": "tag",
#               "value": "SPRO"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Adjective Pronoun",
#               "type": "tag",
#               "value": "APRO"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Adverbial Pronoun",
#               "type": "tag",
#               "value": "ADVPRO"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Predicative Pronoun",
#               "type": "tag",
#               "value": "PRAEDICPRO"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Preposition",
#               "type": "tag",
#               "value": "PR"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Conjunction",
#               "type": "tag",
#               "value": "CONJ"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Particle",
#               "type": "tag",
#               "value": "PART"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Interjection",
#               "type": "tag",
#               "value": "INTJ"
#             },
#             {
#               "category": "pos",
#               "tooltip": "Initial Letter",
#               "type": "tag",
#               "value": "INIT"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Case"
#             },
#             {
#               "category": "case",
#               "tooltip": "Nominative",
#               "type": "tag",
#               "value": "nom"
#             },
#             {
#               "category": "case",
#               "tooltip": "Genitive",
#               "type": "tag",
#               "value": "gen"
#             },
#             {
#               "category": "case",
#               "tooltip": "Dative",
#               "type": "tag",
#               "value": "dat"
#             },
#             {
#               "category": "case",
#               "tooltip": "Accusative",
#               "type": "tag",
#               "value": "acc"
#             },
#             {
#               "category": "case",
#               "tooltip": "Instrumental",
#               "type": "tag",
#               "value": "ins"
#             },
#             {
#               "category": "case",
#               "tooltip": "Locative",
#               "type": "tag",
#               "value": "loc"
#             },
#             {
#               "category": "case",
#               "tooltip": "Vocative",
#               "type": "tag",
#               "value": "voc"
#             },
#             {
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "category": "case",
#               "tooltip": "2nd Genitive",
#               "type": "tag",
#               "value": "gen2"
#             },
#             {
#               "category": "case",
#               "tooltip": "2nd Accusative",
#               "type": "tag",
#               "value": "acc2"
#             },
#             {
#               "category": "case",
#               "tooltip": "2nd Locative",
#               "type": "tag",
#               "value": "loc2"
#             },
#             {
#               "category": "case",
#               "tooltip": "Adnumeral",
#               "type": "tag",
#               "value": "adnum"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Number"
#             },
#             {
#               "category": "case",
#               "tooltip": "Singular",
#               "type": "tag",
#               "value": "sg"
#             },
#             {
#               "category": "case",
#               "tooltip": "Plural",
#               "type": "tag",
#               "value": "pl"
#             },
#             {
#               "type": "header",
#               "value": "Gender"
#             },
#             {
#               "category": "case",
#               "tooltip": "Masculine",
#               "type": "tag",
#               "value": "m"
#             },
#             {
#               "category": "case",
#               "tooltip": "Feminine",
#               "type": "tag",
#               "value": "f"
#             },
#             {
#               "category": "case",
#               "tooltip": "Neuter",
#               "type": "tag",
#               "value": "n"
#             },
#             {
#               "category": "case",
#               "tooltip": "Common",
#               "type": "tag",
#               "value": "mf"
#             },
#             {
#               "type": "header",
#               "value": "Animacy"
#             },
#             {
#               "category": "case",
#               "tooltip": "Animate",
#               "type": "tag",
#               "value": "anim"
#             },
#             {
#               "category": "case",
#               "tooltip": "Inanimate",
#               "type": "tag",
#               "value": "inan"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Mood / Verb form"
#             },
#             {
#               "category": "case",
#               "tooltip": "Indicative",
#               "type": "tag",
#               "value": "indic"
#             },
#             {
#               "category": "case",
#               "tooltip": "Imperative",
#               "type": "tag",
#               "value": "imper"
#             },
#             {
#               "category": "case",
#               "tooltip": "Imperative 2",
#               "type": "tag",
#               "value": "imper2"
#             },
#             {
#               "category": "case",
#               "tooltip": "Infinitive",
#               "type": "tag",
#               "value": "inf"
#             },
#             {
#               "category": "case",
#               "tooltip": "Participle",
#               "type": "tag",
#               "value": "partcp"
#             },
#             {
#               "category": "case",
#               "tooltip": "Gerund",
#               "type": "tag",
#               "value": "ger"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Tense"
#             },
#             {
#               "category": "case",
#               "tooltip": "Present",
#               "type": "tag",
#               "value": "praes"
#             },
#             {
#               "category": "case",
#               "tooltip": "Future",
#               "type": "tag",
#               "value": "fut"
#             },
#             {
#               "category": "case",
#               "tooltip": "Past",
#               "type": "tag",
#               "value": "praet"
#             },
#             {
#               "type": "header",
#               "value": "Person"
#             },
#             {
#               "category": "case",
#               "tooltip": "1st",
#               "type": "tag",
#               "value": "1p"
#             },
#             {
#               "category": "case",
#               "tooltip": "2nd",
#               "type": "tag",
#               "value": "2p"
#             },
#             {
#               "category": "case",
#               "tooltip": "3rd",
#               "type": "tag",
#               "value": "3p"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Voice"
#             },
#             {
#               "category": "case",
#               "tooltip": "Active",
#               "type": "tag",
#               "value": "act"
#             },
#             {
#               "category": "case",
#               "tooltip": "Passive",
#               "type": "tag",
#               "value": "pass"
#             },
#             {
#               "category": "case",
#               "tooltip": "Middle",
#               "type": "tag",
#               "value": "mid"
#             },
#             {
#               "type": "header",
#               "value": "Aspect"
#             },
#             {
#               "category": "case",
#               "tooltip": "Perfective",
#               "type": "tag",
#               "value": "pf"
#             },
#             {
#               "category": "case",
#               "tooltip": "Imperfective",
#               "type": "tag",
#               "value": "ipf"
#             },
#             {
#               "type": "header",
#               "value": "Transitivity"
#             },
#             {
#               "category": "case",
#               "tooltip": "Transitive",
#               "type": "tag",
#               "value": "tran"
#             },
#             {
#               "category": "case",
#               "tooltip": "Inransitive",
#               "type": "tag",
#               "value": "intr"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Degree / Adj. form"
#             },
#             {
#               "category": "case",
#               "tooltip": "Comparative",
#               "type": "tag",
#               "value": "comp"
#             },
#             {
#               "category": "case",
#               "tooltip": "Comparative 2",
#               "type": "tag",
#               "value": "comp2"
#             },
#             {
#               "category": "case",
#               "tooltip": "Superlative",
#               "type": "tag",
#               "value": "super"
#             },
#             {
#               "category": "case",
#               "tooltip": "Full form",
#               "type": "tag",
#               "value": "plen"
#             },
#             {
#               "category": "case",
#               "tooltip": "Short form",
#               "type": "tag",
#               "value": "brev"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Proper names"
#             },
#             {
#               "category": "case",
#               "tooltip": "Name",
#               "type": "tag",
#               "value": "persn"
#             },
#             {
#               "category": "case",
#               "tooltip": "Patronymic",
#               "type": "tag",
#               "value": "patrn"
#             },
#             {
#               "category": "case",
#               "tooltip": "Family name",
#               "type": "tag",
#               "value": "famn"
#             },
#             {
#               "category": "case",
#               "tooltip": "Zoonym",
#               "type": "tag",
#               "value": "zoon"
#             },
#             {
#               "category": "case",
#               "tooltip": "Toponymic",
#               "type": "tag",
#               "value": "topn"
#             }
#           ],
#           [
#             {
#               "type": "header",
#               "value": "Other features"
#             },
#             {
#               "category": "case",
#               "tooltip": "Digit",
#               "type": "tag",
#               "value": "digit"
#             },
#             {
#               "category": "case",
#               "tooltip": "Anomalous form",
#               "type": "tag",
#               "value": "anom"
#             },
#             {
#               "category": "case",
#               "tooltip": "Distortion",
#               "type": "tag",
#               "value": "distort"
#             },
#             {
#               "category": "case",
#               "tooltip": "Abbreviation",
#               "type": "tag",
#               "value": "abbr"
#             },
#             {
#               "category": "case",
#               "tooltip": "Indeclinable",
#               "type": "tag",
#               "value": "0"
#             },
#             {
#               "type": "separator",
#               "value": ""
#             },
#             {
#               "category": "case",
#               "tooltip": "Word in dictionary",
#               "type": "tag",
#               "value": "norm"
#             },
#             {
#               "category": "case",
#               "tooltip": "Word not in dictionary",
#               "type": "tag",
#               "value": "bastard"
#             }
#           ]
#         ]
#       }
#     },
#     "undefined": {
#       "gr_fields_order": []
#     }
#   },
#   "languages": [
#     "chakavian",
#     "english"
#   ],
#   "lemma_table_fields": [],
#   "line_plot_meta": [
#     "year"
#   ],
#   "max_context_expand": 10,
#   "max_docs_retrieve": 9999,
#   "max_hits_retrieve": 10000,
#   "max_words_in_sentence": 40,
#   "media": true,
#   "media_length": 60,
#   "media_youtube": false,
#   "multiple_choice_fields": {},
#   "negative_search_enabled": true,
#   "part_of_collection": false,
#   "primary_languages": [],
#   "query_log": false,
#   "query_timeout": 60,
#   "rtl_languages": [],
#   "search_meta": {
#     "columns": [
#       [
#         {
#           "name": "author",
#           "text": "",
#           "type": "input_text",
#           "value": ""
#         },
#         {
#           "name": "title",
#           "text": "",
#           "type": "input_text",
#           "value": ""
#         },
#         {
#           "name": "",
#           "text": "",
#           "type": "separator",
#           "value": ""
#         },
#         {
#           "name": "year_from",
#           "text": "",
#           "type": "input_number",
#           "value": ""
#         },
#         {
#           "name": "year_to",
#           "text": "",
#           "type": "input_number",
#           "value": ""
#         }
#       ],
#       [
#         {
#           "name": "genre",
#           "text": "",
#           "type": "input_text",
#           "value": ""
#         },
#         {
#           "name": "genre",
#           "text": "dialogue",
#           "type": "option",
#           "value": "dialogue"
#         },
#         {
#           "name": "genre",
#           "text": "Monologue",
#           "type": "option",
#           "value": "monologue"
#         },
#         {
#           "name": "genre",
#           "text": "Experiment",
#           "type": "option",
#           "value": "experiment"
#         }
#       ]
#     ],
#     "stat_options": [
#       "genre",
#       "author",
#       "linguists",
#       "speakers",
#       "title",
#       "year",
#       "speaker",
#       "gender",
#       "birthyear"
#     ]
#   },
#   "search_remove_whitespaces": false,
#   "sent_id_sort_enabled": false,
#   "sentence_meta": [
#     "speaker"
#   ],
#   "start_page_url": "",
#   "text_fields_lowercase": false,
#   "transliterations": [
#     "original",
#     "cyrillic",
#     "UPA"
#   ],
#   "try_restart_elastic": false,
#   "video": false,
#   "viewable_meta": [
#     "filename",
#     "title",
#     "author",
#     "genre",
#     "year",
#     "speakers",
#     "linguists"
#   ],
#   "wf_lowercase": true,
#   "word_fields": [
#     "lemma",
#     "pos",
#     "feats",
#     "gloss"
#   ],
#   "word_search_display_gr": true,
#   "word_table_fields": [
#     "trans_ru"
#   ],
#   "year_sort_enabled": true
# }

# %% [markdown]
# ### 2. Converting `.eaf` files to `.json`

# %% [markdown]
# Setup conversion settings

# %%
cd src_convertors/
mkdir corpus
mv conf_conversion corpus/conf_conversion
cd corpus/conf_conversion
emacs conversion_settings.json

# %% [markdown]
# Replace the `conversion_settings.json` file contents with these settings:

# %% [raw]
# {
#   "languages": ["ckm", "eng"],
#
#   "tier_languages": {
#       "Text@.*": "ckm",
#       "engTrans@.*": "eng"
#   },
#
#   "main_tiers": ["Text@.*"],
#   "aligned_tiers": ["engTrans@.*"],
#
#   "analysis_tiers": {
#       "^Words@.*$": "word",
#       "^Lemma@.*$": "lemma",
#       "^PoS@.*$": "pos",
#       "^Feats@.*$": "gramm",
#       "^Gloss@.*$": "gloss"
#   },
#
#   "one_morph_per_cell": true,
#   "json_indent": 4,
#   "corpus_name": "",
#   "gzip": false,
#   "meta_filename": "",
#   "meta_files_dir": "",
#   "meta_files_ext": "",
#   "meta_files_case_sensitive": true,
#   "media_length": 30,
#   "sent_start": "^|\\s",
#   "sent_end_punc": "[.!?]\\s"
# }

# %%
emacs conf_conversion/categories.json # create categories file

# %% [markdown]
# The `categories.json` can just match the `categories.json` file in the `tsakorpus/conf` directory (for now)

# %% [raw]
# {
#   "beserman": {
#     "1": "pers",
#     "2": "pers",
#     "3": "pers",
#     "A": "pos",
# ... # etc
#   }
# }

# %%
cd .. # go back up to `corpus` directory
mkdir eaf

# %% [markdown]
# Add all .eaf files and their corresponding audio files to the `src_convertors/corpus/eaf` directory

# %%
scp /path/on/local/to/eaf/file.eaf username@corpus.uga.edu:tsakorpus/src_convertors/corpus/eaf/
scp /path/on/local/to/eaf/file.wav username@corpus.uga.edu:tsakorpus/src_convertors/corpus/eaf/
# repeat for all .eaf files

# %% [markdown]
# Ensure that `ffprobe` is installed (for cutting media into clips)

# %%
pip install ffprobe
mkdir -p $HOME/bin
cd $HOME/bin
wget https://johnvansickle.com/ffmpeg/releases/ffmpeg-release-amd64-static.tar.xz
tar -xf ffmpeg-release-amd64-static.tar.xz
cd ffmpeg-*-static
export PATH=$PWD:$PATH

# %% [markdown]
# Navigate to `src_convertors` and convert eaf files to json with `eaf2json.py`

# %%
cd ~/tsakorpus/src_convertors/
python eaf2json.py

# %% [markdown]
# Confirm that the conversion worked by checking in `corpus/json`

# %%
ls corpus/json
ls corpus/media

# %% [markdown]
# Move converted files to correct final folders (to be found by indexator later)

# %%
cd ~/tsakorpus
mkdir corpus
cd corpus
mkdir elic
cd ..
mv -v src_convertors/corpus/json/* corpus/elic/

cd search
mkdir media
cd media
mkdir elic
cd ../..
mv -v src_convertors/corpus/media/* search/media/elic/

# %% [markdown]
# ### 3. Running the indexator

# %% [markdown]
# Download Elasticsearch

# %%
pip install elasticsearch
cd ..
wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-9.0.1-linux-x86_64.tar.gz
tar -xvzf elasticsearch-9.0.0-linux-x86_64.tar.gz
rm elasticsearch-9.0.0-linux-x86_64.tar.gz

# %% [markdown]
# Change Elasticsearch configuration (in `elasticsearch-9.0.0/config/`)

# %%
cd elasticsearch-9.0.0/config
emacs elasticsearch.yml

# %%
# ...
# change settings at bottom of .yml file

# Enable security features 
xpack.security.enabled: false # CHANGED TO FALSE (for now!)

xpack.security.enrollment.enabled: false # CHANGED TO FALSE (for now!)

# Enable encryption for HTTP API client connections, such as Kibana, Logstash, and Agents
xpack.security.http.ssl:
  enabled: true
  keystore.path: certs/http.p12

# Enable encryption and mutual authentication between cluster nodes
xpack.security.transport.ssl:
  enabled: true
  verification_mode: certificate
  keystore.path: certs/transport.p12
  truststore.path: certs/transport.p12
# Create a new cluster with the current node only
# Additional nodes can still join the cluster later
cluster.initial_master_nodes: ["kucera.ling.uga.edu"]

# Allow HTTP API connections from anywhere
# Connections are encrypted and require user authentication
http.host: 0.0.0.0

# Allow other nodes to join the cluster from anywhere
# Connections are encrypted and mutually authenticated
#transport.host: 0.0.0.0

#----------------------- END SECURITY AUTO CONFIGURATION -------------------------

xpack.ml.enabled: false # DISABLED ML FUNCTIONALITY

# %% [markdown]
# Open a new terminal window and run Elasticsearch, keep it running for the rest of the duration

# %%
cd elasticsearch-9.0.0
./bin/elasticsearch

# %% [markdown]
# Make changes to `indexator.py`, give script direct location of Elasticsearch server

# %%
# ...
# find indexator class and change line at bottom
class Indexator:
    """
    Contains methods for loading the JSON documents in the corpus
    database.
    """
    SETTINGS_DIR = '../conf'
    MAX_MEM_DICT_SIZE = 100000
    rxBadFileName = re.compile('[^\\w_.-]*', flags=re.DOTALL)

    def __init__(self, overwrite=False):
        random.seed(datetime.now().timestamp())
        self.overwrite = overwrite  # whether to overwrite an existing index without asking
        with open(os.path.join(self.SETTINGS_DIR, 'corpus.json'),
                  'r', encoding='utf-8') as fSettings:
            self.settings = json.load(fSettings)
        self.j2h = JSON2HTML(settings=self.settings)
        self.name = self.settings['corpus_name']
        self.languages = self.settings['languages']
        if len(self.languages) <= 0:
            self.languages = [self.name]
        self.input_format = self.settings['input_format']
        self.corpus_dir = os.path.join('../corpus', self.name)
        self.lowerWf = False
        if 'wf_lowercase' not in self.settings or self.settings['wf_lowercase']:
            self.lowerWf = True
        self.iterSent = None
        if self.input_format in ['json', 'json-gzip']:
            self.iterSent = JSONDocReader(format=self.input_format,
                                          settings=self.settings)

        # Make sure only commonly used word fields and those listed
        # in corpus.json get into the words index.
        self.goodWordFields = [
            'lex',          # lemma
            'wf',           # word form (for search)
            'wf_display',   # word form (for display; optional)
            'parts',        # morpheme breaks in the word form
            'gloss',        # glosses (for display)
            'gloss_index',  # glosses (for search)
            'n_ana'         # number of analyses
        ]
        self.additionalWordFields = set()
        self.additionalLemmaFields = set()
        self.excludeFromDict = {}
        if 'word_fields' in self.settings:
            self.additionalWordFields |= set(self.settings['word_fields'])
        if 'word_table_fields' in self.settings:
            self.additionalWordFields |= set(self.settings['word_table_fields'])
        if 'lemma_table_fields' in self.settings:
            self.additionalLemmaFields = set(self.settings['lemma_table_fields'])
        if 'accidental_word_fields' in self.settings:
            self.additionalWordFields -= set(self.settings['accidental_word_fields'])
            self.additionalLemmaFields -= set(self.settings['accidental_word_fields'])
        if 'exclude_from_dict' in self.settings:
            self.excludeFromDict = {k: re.compile(v) for k, v in self.settings['exclude_from_dict'].items()}
        f = open(os.path.join(self.SETTINGS_DIR, 'categories.json'),
                 'r', encoding='utf-8')
        categories = json.loads(f.read())
        f.close()
        self.goodWordFields += ['gr.' + v for lang in categories
                                for v in categories[lang].values()]
        self.goodWordFields = set(self.goodWordFields)
        self.characterRegexes = {}

        self.pd = PrepareData()

        # Initialize Elasticsearch connection
        self.es = None
        if 'elastic_url' in self.settings and len(self.settings['elastic_url']) > 0:
            # Connect to a non-default URL or supply username and password
            self.es = Elasticsearch([self.settings['elastic_url']], timeout=60)
        else:
            # self.es = Elasticsearch(timeout=60) # ORIGINAL LINE
            self.es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60) # UPDATED LINE (most updated version of library needs exact location of server)
                                                                                 # default is 9200
        self.es_ic = IndicesClient(self.es)

# %% [markdown]
# Go back to the first terminal window and run the indexator

# %%
# install any python packages that might still be needed after installing requirements.txt
pip install ijson
pip install werkzeug
pip install jinja2
pip install flask
pip install sqlitedict

# %%
python indexator.py

# %% [markdown]
# ### 4. Open corpus locally

# %% [markdown]
# Repeat previous code change for `tsakorpus.wsgi`

# %%
# make 
cd ~/tsakorpus
cd search
emacs search_engine/client.py

# %%
# ...
# find search client and change code at bottom
class SearchClient:
    """
    Contains methods for querying the corpus database.
    """

    def __init__(self, settings_dir, settings):
        self.settings = settings
        self.name = self.settings.corpus_name
        esTimeout = max(20, self.settings.query_timeout)
        self.es = None
        if self.settings.elastic_url is not None and len(self.settings.elastic_url) > 0:
            # Connect to a non-default URL or supply username and password
            self.es = Elasticsearch([self.settings.elastic_url], timeout=esTimeout)
        else:
            self.es = Elasticsearch(hosts=["http://localhost:9200"], timeout=esTimeout) # same change as indexator.py, add `hosts` parameter

# %% [markdown]
# Make changes in `search/web_app/translations` directory to fix naming on final webpage

# %%
cd ~/tsakorpus/search/web_app/translations/en
emacs corpus-specific.txt

# %% [raw]
# corpus_title	Endangered Languages in Contact in Istria and Kvarner, Croatia (ELIC)

# %%
emacs languages.txt

# %% [raw]
# all	all
# undefined	undefined
# comments	comments
# positive	positive
# negative	negative
# notes	notes
# note	notes
# ref	ID
# id	ID
#
# abaza	Abaza
# acrhi	Archi
# adyghe	Adyghe
# albanian	Albanian
# armenian	Armenian
# armenian_translit	Armenian (translit.)
# bangime	Bangime
# bashkir	Bashkir
# belarusian	Belarusian
# beserman	Beserman
# bulgarian	Bulgarian
# buryat	Buryat
# chinese	Chinese
# chuvash	Chuvash
# chuvash_cyr	Chuvash (cyrillic)
# dargwa	Dargwa
# dogon	Dogon
# english	English
# english_note	English (note)
# erzya	Erzya
# estonian	Estonian
# finnish	Finnish
# french	French
# german	German
# ginyanga	Ginyanga
# gizey	Gizey
# greek	Greek
# guro	Guro
# hill_mari	Hill Mari
# hungarian	Hungarian
# italian	Italian
# joola	Jо́ola (Eegimaa)
# kafire	Kafire
# kalmyk	Kalmyk
# kamas	Kamas
# kazakh	Kazakh
# komi	Komi
# komi-zyrian	Komi-Zyrian
# komi_permyak	Komi-Permyak
# komi_zyrian	Komi-Zyrian
# latvian	Latvian
# limba	Limba
# lithuanian	Lithuanian
# macedonian	Macedonian
# macedonian_cyr	Macedonian (cyrillic)
# meadow_mari	Meadow Mari
# moksha	Moksha
# mundabli	Mundabli
# mwan	Mwan
# nganasan	Nganasan
# ossetic	Ossetic
# ossetic_digor	Digor Ossetic
# ossetic_iron	Iron Ossetic
# polish	Polish
# romani	Romani
# russian	Russian
# san	San
# selkup	Selkup
# senufo	Senufo
# spanish	Spanish
# swedish	Swedish
# tatar	Tatar
# tsakhur	Tsakhur
# tsakonian	Tsakonian
# udihe	Udihe
# udmurt	Udmurt
# ukrainian	Ukrainian
# ut-main	u̠t-Ma'in
# wan	Wan
# yakut	Yakut
# yiddish	Yiddish
# chakavian	Chakavian

# %% [markdown]
# Run `tsakorpus.wsgi`

# %%
# install any needed packages
pip install xlsxwriter==3.0.9
pip install flask_babel

# %%
python tsakorpus.wsgi

# %% [markdown]
# Get output and port number

# %%
compiling catalog translations_pybabel/en/LC_MESSAGES/messages.po to translations_pybabel/en/LC_MESSAGES/messages.mo
compiling catalog translations_pybabel/ru/LC_MESSAGES/messages.po to translations_pybabel/ru/LC_MESSAGES/messages.mo
compiling catalog translations_pybabel/fr/LC_MESSAGES/messages.po to translations_pybabel/fr/LC_MESSAGES/messages.mo
Interface translations compiled.
 * Serving Flask app 'web_app' (lazy loading)
 * Environment: production
   WARNING: This is a development server. Do not use it in a production deployment.
   Use a production WSGI server instead.
 * Debug mode: on
 * Running on all addresses.
   WARNING: This is a development server. Do not use it in a production deployment.
 * Running on http://172.22.162.16:7342/ (Press CTRL+C to quit) # port is 7342

# %% [markdown]
# Open another terminal window and connect using ssh and the port number

# %%
ssh -L 7342:localhost:7342 username@corpus.uga.edu

# %% [markdown]
# Go to the following URL in your web browser - if everything was done correctly, you should see the corpus webpage

# %% [raw]
# http://localhost:7342/search # must use "/search", root returns a 404

# %% [markdown]
# The Tsakorpus creator also allowed for a different way to configure the corpus with the `corpus.json` file with a GUI accessible through

# %% [raw]
# http://localhost:7342/config

# %% [markdown]
# If you set the config settings this way, be sure to move the new `.json` file to the correct location (`~/tsakorpus/conf`) as described in the [docs](https://tsakorpus.readthedocs.io/en/latest/configuration.html)

# %% [markdown]
# ## Additional Changes
# Here are extra changes that were made after the initial setup for bug fixes, changing configs, etc.

# %% [markdown]
# ### Adding speaker to metadata menu

# %%
cd ~
cd tsakorpus/search/web_app
emacs response_processors

# %%
# find this function:
def process_sentence_header(self, sentSource, format='html', curLocale=''):
    """
    Build the little Metadata pop-up for each sentence in search results.
    We fetch the document-level metadata, overlay the sentence-level
    metadata from sentSource, then render the modal table.
    """
    # and replace its content with this below:
    docID = sentSource['doc_id']
    raw = self.sc.get_doc_by_id(docID)
    if (raw is None
        or 'hits' not in raw
        or 'hits' not in raw['hits']
        or len(raw['hits']['hits']) == 0
        or '_source' not in raw['hits']['hits'][0]):
        # nothing to show
        if format == 'csv':
            return ['']
        else:
            return render_template(
                'search_results/sentence_header.html',
                fulltext_view_enabled=False
            )

    source = raw['hits']['hits'][0]['_source']
    doc_meta = source.get('meta', {}).copy()
    sent_meta = sentSource.get('meta', {})
    if isinstance(sent_meta, dict):
        doc_meta.update(sent_meta)

    for k,v in list(doc_meta.items()):
        if isinstance(v, list):
            doc_meta[k] = '; '.join(v)
        elif isinstance(v, int):
            doc_meta[k] = str(v)

    dateDisplay = ''
    if 'year' in doc_meta:
        dateDisplay = str(doc_meta['year'])
    elif 'year_from' in doc_meta and 'year_to' in doc_meta:
        dateDisplay = str(doc_meta['year_from'])
        if doc_meta['year_to'] != doc_meta['year_from']:
            dateDisplay += '–' + str(doc_meta['year_to'])

    curLocale = '_' + curLocale
    if (self.settings.localized_meta_values
        and len(curLocale) > 1):
        for key in list(doc_meta.keys()):
            if key.endswith(curLocale):
                base = key[:-len(curLocale)]
                if base in self.settings.localized_meta_values:
                    doc_meta[base] = doc_meta[key]
                    del doc_meta[key]

    metaHtml = render_template(
        'modals/metadata_table.html',
        data={'meta': doc_meta},
        viewable_meta=self.settings.viewable_meta,
        sentence_meta=self.settings.sentence_meta
    )
    metaHtml = html.escape(metaHtml)

    if format == 'csv':
        result = ['']
        if 'title' in doc_meta:
            result[0] += '"' + doc_meta['title'] + '" '
        else:
            result[0] += '"???" '
        if (self.authorMeta in doc_meta
            and doc_meta[self.authorMeta]):
            result[0] += '(' + doc_meta[self.authorMeta] + ') '
        if 'issue' in doc_meta and doc_meta['issue']:
            result[0] += doc_meta['issue'] + ' '
        if dateDisplay:
            result[0] += '[' + dateDisplay + ']'
        meta = {
            self.rxKW.sub('', k): v
            for k,v in doc_meta.items()
            if (self.rxKW.sub('', k) in self.settings.viewable_meta
                and k not in ['filename','filename_kw'])
        }
        sortedFields = [
            f for f in self.settings.viewable_meta
            if f not in ['filename','filename_kw']
                and f not in self.settings.sentence_meta
        ]
        for f in sortedFields:
            val = meta.get(f,'').replace('\t',' ')
            new = f'[{f}: {val}]'
            if new not in result:
                result.append(new)
        return result

    return render_template(
        'search_results/sentence_header.html',
        fulltext_view_enabled=self.settings.fulltext_view_enabled,
        author_meta=self.authorMeta,
        date_display=dateDisplay,
        metaHtml=metaHtml,
        meta=doc_meta
    )

# %% [markdown]
# ### Bug Fixes

# %% [markdown]
# Navigate to `~/tsakorpus/search/search_engine/query_parsers.py` and find the `make_simple_term_query()` function, change the return statement

# %%
def make_simple_term_query(self, text, field, lang, keyword_query=False, rewrite=True):
    """
    Make a term query that will become one of the inner parts
    of the compound bool query. Recognize simple wildcards and regexps.
    If the field is "ana.gr", find categories for every gramtag. If no
    category is available for some tag, return empty query.
    """
    # . . .
    return {'match': {field: text}} # ADDED CHANGE: changed from {} to {field: text}

# %% [markdown]
# Locate the `html2es()` function in the same file and make the following changes

# %%
def html2es(self, htmlQuery, page=1, query_size=10, sortOrder='random',
                randomSeed=None, searchOutput='sentences', groupBy='word',
                distances=None, includeNextWordField=False,
                after_key=None, highlight=True):
        """
        Make and return a ES query out of the HTML form data.
        """
        # --- ADDED BLOCK: Convert numeric lang1 to language name ---
        if 'lang1' in htmlQuery and htmlQuery['lang1'].isdigit():
            idx = int(htmlQuery['lang1'])
            if idx < len(self.settings.languages):
                htmlQuery['lang1'] = self.settings.languages[idx]
        # -----------------------------------------------------------        
        # --- ADDED BLOCK: Handle generic query parameter "q" ---
        if 'q' in htmlQuery and 'n_words' not in htmlQuery:
            htmlQuery['n_words'] = "1"
            htmlQuery['wf1'] = htmlQuery['q']
        # ----------------------------------------------------------
        query_from, langID, lang, searchIndex =\
            self.check_html_parameters(htmlQuery, page, query_size, searchOutput)
        if query_from is None:
            return {'query': {'match_none': {}}} # ADDED CHANGE: changed from {'match_none': ''} to {'match_none': {}}
        # . . . 
        # . . . navigate to bottom of function
        # . . . 
        else:
            queryDict = {'query': {'match_none': {}}} # ADDED CHANGE: changed from {'match_none': ''} to {'match_none': {}}
        return queryDict

# %% [markdown]
# Navigate to `~/tsakorpus/search/web_app/response_processors.py` and make the following changes to `transliterate_baseline()`

# %%
def transliterate_baseline(self, text, lang, translit=None):
    if translit is None or lang not in self.settings.languages:
        return text
    # ADDED CHANGE: fixing error by making sure 'text' is actually a string
    if not text:
        text = ''
    elif not isinstance(text, (str, bytes)):
        text = str(text)
    # end of added change
    # . . .
